# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,1,100)
y = np.sin(2*np.pi*x)

fig = plt.figure()
sub = fig.add_subplot(111)
sub.plot(x,y,label='$y=\sin(x)$')
sub.set_xlabel('x')
sub.set_ylabel('y')
sub.legend()
plt.show()
