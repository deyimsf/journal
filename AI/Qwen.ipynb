# %%
# !pip install transformers>=4.32.0,<4.38.0
# !pip install accelerate
# !pip install tiktoken
# !pip install einops
# !pip install transformers_stream_generator==0.0.4
# !pip install scipy
# !pip install modelscope
# Out:
# zsh:1: 4.32.0, not found
# Collecting accelerate
#   Obtaining dependency information for accelerate from https://files.pythonhosted.org/packages/15/33/b6b4ad5efa8b9f4275d4ed17ff8a44c97276171341ba565fdffb0e3dc5e8/accelerate-0.33.0-py3-none-any.whl.metadata
#   Downloading accelerate-0.33.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from accelerate) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from accelerate) (23.1)
# Requirement already satisfied: psutil in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyyaml in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from accelerate) (6.0)
# Requirement already satisfied: torch>=1.10.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from accelerate) (2.2.1)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from accelerate) (0.23.2)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.9.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.5.0)
# Requirement already satisfied: requests in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.10.0)
# Requirement already satisfied: sympy in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (1.11.1)
# Requirement already satisfied: networkx in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1)
# Requirement already satisfied: jinja2 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-0.33.0-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 316.7 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: accelerate
# Successfully installed accelerate-0.33.0
# Requirement already satisfied: tiktoken in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from tiktoken) (2022.7.9)
# Requirement already satisfied: requests>=2.26.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from tiktoken) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests>=2.26.0->tiktoken) (2024.2.2)
# Requirement already satisfied: einops in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (0.8.0)
# Collecting transformers_stream_generator==0.0.4
#   Downloading transformers-stream-generator-0.0.4.tar.gz (12 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: transformers>=4.26.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers_stream_generator==0.0.4) (4.41.2)
# Requirement already satisfied: filelock in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (3.9.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (0.23.2)
# Requirement already satisfied: numpy>=1.17 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (1.24.3)
# Requirement already satisfied: packaging>=20.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (6.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (2022.7.9)
# Requirement already satisfied: requests in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (2.31.0)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (0.4.3)
# Requirement already satisfied: tqdm>=4.27 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from transformers>=4.26.1->transformers_stream_generator==0.0.4) (4.65.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers>=4.26.1->transformers_stream_generator==0.0.4) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.23.0->transformers>=4.26.1->transformers_stream_generator==0.0.4) (4.10.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.26.1->transformers_stream_generator==0.0.4) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.26.1->transformers_stream_generator==0.0.4) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.26.1->transformers_stream_generator==0.0.4) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests->transformers>=4.26.1->transformers_stream_generator==0.0.4) (2024.2.2)
# Building wheels for collected packages: transformers_stream_generator
#   Building wheel for transformers_stream_generator (setup.py) ... done
#   Created wheel for transformers_stream_generator: filename=transformers_stream_generator-0.0.4-py3-none-any.whl size=12319 sha256=80342859a94d55fb1a70bf9b818245265620fde798dc2c4c15bea77d8ff07f7f
#   Stored in directory: /Users/mashunfeng/Library/Caches/pip/wheels/5a/c5/92/43af1fc20acdb3cbc708992aed015ae2992fd922898c4bef31
# Successfully built transformers_stream_generator
# Installing collected packages: transformers_stream_generator
# Successfully installed transformers_stream_generator-0.0.4
# Requirement already satisfied: scipy in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (1.11.1)
# Requirement already satisfied: numpy<1.28.0,>=1.21.6 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from scipy) (1.24.3)
# Collecting modelscope
#   Obtaining dependency information for modelscope from https://files.pythonhosted.org/packages/38/37/9fe505ebc67ba5e0345a69d6e8b2ee8630523975b484d221691ef60182bd/modelscope-1.16.1-py3-none-any.whl.metadata
#   Downloading modelscope-1.16.1-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 kB 604.5 kB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.25 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from modelscope) (2.31.0)
# Requirement already satisfied: tqdm>=4.64.0 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from modelscope) (4.65.0)
# Requirement already satisfied: urllib3>=1.26 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from modelscope) (1.26.16)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests>=2.25->modelscope) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests>=2.25->modelscope) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/mashunfeng/anaconda3/lib/python3.11/site-packages (from requests>=2.25->modelscope) (2024.2.2)
# Downloading modelscope-1.16.1-py3-none-any.whl (5.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 8.4 MB/s eta 0:00:0000:0100:01
# Installing collected packages: modelscope
# Successfully installed modelscope-1.16.1

# %%
from modelscope import AutoModelForCausalLM, AutoTokenizer
from modelscope import GenerationConfig

# 可选的模型包括: "qwen/Qwen-7B-Chat", "qwen/Qwen-14B-Chat"
tokenizer = AutoTokenizer.from_pretrained("qwen/Qwen-1_8B-Chat", trust_remote_code=True)
model = AutoModelForCausalLM.from_pretrained("qwen/Qwen-1_8B-Chat", device_map="auto", trust_remote_code=True, fp16=True).eval()
model.generation_config = GenerationConfig.from_pretrained("qwen/Qwen-1_8B-Chat", trust_remote_code=True) # 可指定不同的生成长度、top_p等相关超参

response, history = model.chat(tokenizer, "你好", history=None)
print(response)
response, history = model.chat(tokenizer, "浙江的省会在哪里？", history=history) 
print(response)
response, history = model.chat(tokenizer, "它有什么好玩的景点", history=history)
print(response)
# Out:
# 2024-07-24 13:57:46,935 - modelscope - WARNING - Model revision not specified, use revision: v1.0.0
# 2024-07-24 13:57:48,560 - modelscope - WARNING - Model revision not specified, use revision: v1.0.0
#
# Downloading:   0%|                                                                           | 0.00/1.90G [00:00<?, ?B/s]
# Downloading:  33%|██████████████████████                                             | 640M/1.90G [01:20<02:10, 10.5MB/s]
# Downloading:  38%|█████████████████████████▌                                         | 741M/1.90G [00:11<00:00, 1.56GB/s]
# Downloading:  38%|█████████████████████████▌                                         | 742M/1.90G [00:11<00:24, 51.6MB/s]
# Downloading:  38%|█████████████████████████▋                                         | 744M/1.90G [00:11<00:25, 49.6MB/s]
# Downloading:  41%|███████████████████████████▊                                       | 806M/1.90G [00:19<00:45, 26.3MB/s]
# Downloading:  43%|████████████████████████████▉                                      | 840M/1.90G [00:23<00:56, 20.6MB/s]
# Downloading:  44%|█████████████████████████████▋                                     | 861M/1.90G [00:25<01:01, 18.4MB/s]
# Downloading:  45%|██████████████████████████████▏                                    | 875M/1.90G [00:27<01:06, 17.0MB/s]
# Downloading:  46%|██████████████████████████████▍                                    | 885M/1.90G [00:28<01:08, 16.2MB/s]
# Downloading:  46%|██████████████████████████████▋                                    | 892M/1.90G [00:29<01:10, 15.6MB/s]
# Downloading:  46%|██████████████████████████████▉                                    | 897M/1.90G [00:29<01:14, 14.7MB/s]
# Downloading:  46%|███████████████████████████████                                    | 901M/1.90G [00:30<01:14, 14.6MB/s]
# Downloading:  46%|███████████████████████████████▏                                   | 904M/1.90G [00:30<01:17, 14.0MB/s]
# Downloading:  47%|███████████████████████████████▏                                   | 907M/1.90G [00:30<01:20, 13.5MB/s]
# Downloading:  47%|███████████████████████████████▎                                   | 909M/1.90G [00:30<01:20, 13.5MB/s]
# Downloading:  47%|███████████████████████████████▍                                   | 911M/1.90G [00:30<01:21, 13.4MB/s]
# Downloading:  47%|███████████████████████████████▍                                   | 913M/1.90G [00:31<01:32, 11.7MB/s]
# Downloading:  47%|███████████████████████████████▌                                   | 915M/1.90G [00:31<01:26, 12.5MB/s]
# Downloading:  47%|███████████████████████████████▌                                   | 917M/1.90G [00:31<01:32, 11.6MB/s]
# Downloading:  47%|███████████████████████████████▋                                   | 919M/1.90G [00:31<01:42, 10.5MB/s]
# Downloading:  47%|███████████████████████████████▊                                   | 922M/1.90G [00:32<01:47, 9.97MB/s]
# Downloading:  48%|███████████████████████████████▊                                   | 924M/1.90G [00:32<01:48, 9.83MB/s]
# Downloading:  48%|███████████████████████████████▉                                   | 926M/1.90G [00:32<02:02, 8.73MB/s]
# Downloading:  48%|███████████████████████████████▉                                   | 928M/1.90G [00:33<02:13, 8.01MB/s]
# Downloading:  48%|████████████████████████████████                                   | 929M/1.90G [00:33<02:15, 7.88MB/s]
# Downloading:  48%|████████████████████████████████                                   | 932M/1.90G [00:33<02:41, 6.57MB/s]
# Downloading:  48%|████████████████████████████████▏                                  | 934M/1.90G [00:33<02:37, 6.74MB/s]
# Downloading:  48%|████████████████████████████████▏                                  | 935M/1.90G [00:34<02:44, 6.44MB/s]
# Downloading:  48%|████████████████████████████████▏                                  | 936M/1.90G [00:34<02:50, 6.19MB/s]
# Downloading:  48%|████████████████████████████████▎                                  | 938M/1.90G [00:34<02:24, 7.33MB/s]
# Downloading:  48%|████████████████████████████████▎                                  | 939M/1.90G [00:34<02:35, 6.78MB/s]
# Downloading:  48%|████████████████████████████████▍                                  | 942M/1.90G [00:35<02:20, 7.48MB/s]
# Downloading:  49%|████████████████████████████████▌                                  | 944M/1.90G [00:35<02:03, 8.52MB/s]
# Downloading:  49%|████████████████████████████████▌                                  | 945M/1.90G [00:35<02:03, 8.49MB/s]
# Downloading:  49%|████████████████████████████████▌                                  | 946M/1.90G [00:35<02:13, 7.84MB/s]
# Downloading:  49%|████████████████████████████████▋                                  | 948M/1.90G [00:35<01:46, 9.85MB/s]
# Downloading:  49%|████████████████████████████████▋                                  | 950M/1.90G [00:35<02:09, 8.05MB/s]
# Downloading:  49%|████████████████████████████████▊                                  | 951M/1.90G [00:36<02:04, 8.39MB/s]
# Downloading:  49%|████████████████████████████████▊                                  | 952M/1.90G [00:36<02:08, 8.09MB/s]
# Downloading:  49%|████████████████████████████████▊                                  | 953M/1.90G [00:36<02:13, 7.79MB/s]
# Downloading:  49%|████████████████████████████████▊                                  | 954M/1.90G [00:36<02:22, 7.31MB/s]
# Downloading:  49%|████████████████████████████████▉                                  | 955M/1.90G [00:36<02:35, 6.67MB/s]
# Downloading:  49%|████████████████████████████████▉                                  | 957M/1.90G [00:36<02:18, 7.47MB/s]
# Downloading:  49%|█████████████████████████████████                                  | 958M/1.90G [00:37<02:10, 7.95MB/s]
# Downloading:  49%|█████████████████████████████████                                  | 959M/1.90G [00:37<01:39, 10.4MB/s]
# Downloading:  49%|█████████████████████████████████                                  | 961M/1.90G [00:37<01:50, 9.30MB/s]
# Downloading:  50%|█████████████████████████████████▏                                 | 963M/1.90G [00:37<02:20, 7.35MB/s]
# Downloading:  50%|█████████████████████████████████▎                                 | 966M/1.90G [00:38<02:17, 7.47MB/s]
# Downloading:  50%|█████████████████████████████████▍                                 | 970M/1.90G [00:38<01:59, 8.56MB/s]
# Downloading:  50%|█████████████████████████████████▍                                 | 972M/1.90G [00:38<01:55, 8.84MB/s]
# Downloading:  50%|█████████████████████████████████▌                                 | 973M/1.90G [00:38<02:04, 8.16MB/s]
# Downloading:  50%|█████████████████████████████████▌                                 | 975M/1.90G [00:39<02:02, 8.30MB/s]
# Downloading:  50%|█████████████████████████████████▋                                 | 977M/1.90G [00:39<01:45, 9.61MB/s]
# Downloading:  50%|█████████████████████████████████▋                                 | 979M/1.90G [00:39<02:12, 7.62MB/s]
B/s]
# Downloading:  82%|██████████████████████████████████████████████████████            | 1.56G/1.90G [01:47<00:41, 8.97MB/s]
# Downloading:  82%|██████████████████████████████████████████████████████            | 1.56G/1.90G [01:48<00:42, 8.57MB/s]
# Downloading:  82%|██████████████████████████████████████████████████████▏           | 1.56G/1.90G [01:48<00:37, 9.76MB/s]
# Downloading:  82%|██████████████████████████████████████████████████████▏           | 1.56G/1.90G [01:48<00:37, 9.64MB/s]
# Downloading:  82%|██████████████████████████████████████████████████████▏           | 1.56G/1.90G [01:48<00:41, 8.76MB/s]
# Downloading:  82%|██████████████████████████████████████████████████████▎           | 1.56G/1.90G [01:48<00:43, 8.26MB/s]
# Downloading:  82%|██████████████████████████████████████████████████████▎           | 1.56G/1.90G [01:48<00:35, 10.2MB/s]
# Downloading:  82%|██████████████████████████████████████████████████████▍           | 1.57G/1.90G [01:48<00:35, 10.1MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▍           | 1.57G/1.90G [01:49<00:38, 9.31MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▌           | 1.57G/1.90G [01:49<00:45, 7.70MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▌           | 1.57G/1.90G [01:49<00:38, 9.11MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▋           | 1.57G/1.90G [01:50<01:11, 4.87MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▋           | 1.57G/1.90G [01:51<01:37, 3.57MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▋           | 1.58G/1.90G [01:51<01:32, 3.75MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▊           | 1.58G/1.90G [01:51<01:07, 5.14MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▉           | 1.58G/1.90G [01:51<01:05, 5.28MB/s]
# Downloading:  83%|██████████████████████████████████████████████████████▉           | 1.58G/1.90G [01:52<00:51, 6.58MB/s]
# Downloading:  83%|███████████████████████████████████████████████████████           | 1.58G/1.90G [01:52<00:44, 7.66MB/s]
# Downloading:  84%|███████████████████████████████████████████████████████           | 1.59G/1.90G [01:52<00:41, 8.08MB/s]
# ...
# 你好！有什么我能帮你的吗？
# 浙江省的省会是杭州。
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 13
#      11 response, history = model.chat(tokenizer, "浙江的省会在哪里？", history=history)
#      12 print(response)
# ---> 13 response, history = model.chat(tokenizer, "它有什么好玩的景点", history=history)
#      14 print(response)
#
# File ~/.cache/huggingface/modules/transformers_modules/Qwen-1_8B-Chat/modeling_qwen.py:1139, in QWenLMHeadModel.chat(self, tokenizer, query, history, system, stream, stop_words_ids, generation_config, **kwargs)
#    1135 stop_words_ids.extend(get_stop_words_ids(
#    1136     generation_config.chat_format, tokenizer
#    1137 ))
#    1138 input_ids = torch.tensor([context_tokens]).to(self.device)
# -> 1139 outputs = self.generate(
#    1140             input_ids,
#    1141             stop_words_ids=stop_words_ids,
#    1142             return_dict_in_generate=False,
#    1143             generation_config=generation_config,
#    1144             **kwargs,
#    1145         )
#    1147 response = decode_tokens(
#    1148     outputs[0],
#    1149     tokenizer,
#    (...)
#    1154     errors='replace'
#    1155 )
#    1157 # as history is a copy of the user inputs,
#    1158 # we can always return the new turn to the user.
#    1159 # separating input history and output history also enables the user
#    1160 # to implement more complex history management
#
# File ~/.cache/huggingface/modules/transformers_modules/Qwen-1_8B-Chat/modeling_qwen.py:1261, in QWenLMHeadModel.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, **kwargs)
#    1258     else:
#    1259         logits_processor.append(stop_words_logits_processor)
# -> 1261 return super().generate(
#    1262     inputs,
#    1263     generation_config=generation_config,
#    1264     logits_processor=logits_processor,
#    1265     stopping_criteria=stopping_criteria,
#    1266     prefix_allowed_tokens_fn=prefix_allowed_tokens_fn,
#    1267     synced_gpus=synced_gpus,
#    1268     assistant_model=assistant_model,
#    1269     streamer=streamer,
#    1270     **kwargs,
#    1271 )
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:1758, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1750     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    1751         input_ids=input_ids,
#    1752         expand_size=generation_config.num_return_sequences,
#    1753         is_encoder_decoder=self.config.is_encoder_decoder,
#    1754         **model_kwargs,
#    1755     )
#    1757     # 13. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 1758     result = self._sample(
#    1759         input_ids,
#    1760         logits_processor=prepared_logits_processor,
#    1761         logits_warper=prepared_logits_warper,
#    1762         stopping_criteria=prepared_stopping_criteria,
#    1763         generation_config=generation_config,
#    1764         synced_gpus=synced_gpus,
#    1765         streamer=streamer,
#    1766         **model_kwargs,
#    1767     )
#    1769 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    1770     # 11. prepare logits warper
#    1771     prepared_logits_warper = (
#    1772         self._get_logits_warper(generation_config) if generation_config.do_sample else None
#    1773     )
#
# File ~/anaconda3/lib/python3.11/site-packages/transformers/generation/utils.py:2397, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, logits_warper, **model_kwargs)
#    2394 model_inputs = self.prepare_inputs_for_generation(input_ids, **model_kwargs)
#    2396 # forward pass to get next token
# -> 2397 outputs = self(
#    2398     **model_inputs,
#    2399     return_dict=True,
#    2400     output_attentions=output_attentions,
#    2401     output_hidden_states=output_hidden_states,
#    2402 )
#    2404 if synced_gpus and this_peer_finished:
#    2405     continue  # don't waste resources running the code we don't need
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/accelerate/hooks.py:169, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     167         output = module._old_forward(*args, **kwargs)
#     168 else:
# --> 169     output = module._old_forward(*args, **kwargs)
#     170 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/Qwen-1_8B-Chat/modeling_qwen.py:1045, in QWenLMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict)
#    1023 def forward(
#    1024     self,
#    1025     input_ids: Optional[torch.LongTensor] = None,
#    (...)
#    1038     return_dict: Optional[bool] = None,
#    1039 ) -> Union[Tuple, CausalLMOutputWithPast]:
#    1041     return_dict = (
#    1042         return_dict if return_dict is not None else self.config.use_return_dict
#    1043     )
# -> 1045     transformer_outputs = self.transformer(
#    1046         input_ids,
#    1047         past_key_values=past_key_values,
#    1048         attention_mask=attention_mask,
#    1049         token_type_ids=token_type_ids,
#    1050         position_ids=position_ids,
#    1051         head_mask=head_mask,
#    1052         inputs_embeds=inputs_embeds,
#    1053         encoder_hidden_states=encoder_hidden_states,
#    1054         encoder_attention_mask=encoder_attention_mask,
#    1055         use_cache=use_cache,
#    1056         output_attentions=output_attentions,
#    1057         output_hidden_states=output_hidden_states,
#    1058         return_dict=return_dict,
#    1059     )
#    1060     hidden_states = transformer_outputs[0]
#    1062     lm_logits = self.lm_head(hidden_states)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/.cache/huggingface/modules/transformers_modules/Qwen-1_8B-Chat/modeling_qwen.py:893, in QWenModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     882     outputs = torch.utils.checkpoint.checkpoint(
#     883         create_custom_forward(block),
#     884         hidden_states,
#    (...)
#     890         encoder_attention_mask,
#     891     )
#     892 else:
# --> 893     outputs = block(
#     894         hidden_states,
#     895         layer_past=layer_past,
#     896         rotary_pos_emb_list=rotary_pos_emb_list,
#     897         attention_mask=attention_mask,
#     898         head_mask=head_mask[i],
#     899         encoder_hidden_states=encoder_hidden_states,
#     900         encoder_attention_mask=encoder_attention_mask,
#     901         use_cache=use_cache,
#     902         output_attentions=output_attentions,
#     903     )
#     905 hidden_states = outputs[0]
#     906 if use_cache is True:
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/accelerate/hooks.py:169, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     167         output = module._old_forward(*args, **kwargs)
#     168 else:
# --> 169     output = module._old_forward(*args, **kwargs)
#     170 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/Qwen-1_8B-Chat/modeling_qwen.py:612, in QWenBlock.forward(self, hidden_states, rotary_pos_emb_list, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions)
#     598 def forward(
#     599     self,
#     600     hidden_states: Optional[Tuple[torch.FloatTensor]],
#    (...)
#     608     output_attentions: Optional[bool] = False,
#     609 ):
#     610     layernorm_output = self.ln_1(hidden_states)
# --> 612     attn_outputs = self.attn(
#     613         layernorm_output,
#     614         rotary_pos_emb_list,
#     615         layer_past=layer_past,
#     616         attention_mask=attention_mask,
#     617         head_mask=head_mask,
#     618         use_cache=use_cache,
#     619         output_attentions=output_attentions,
#     620     )
#     621     attn_output = attn_outputs[0]
#     623     outputs = attn_outputs[1:]
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/accelerate/hooks.py:169, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     167         output = module._old_forward(*args, **kwargs)
#     168 else:
# --> 169     output = module._old_forward(*args, **kwargs)
#     170 return module._hf_hook.post_forward(module, output)
#
# File ~/.cache/huggingface/modules/transformers_modules/Qwen-1_8B-Chat/modeling_qwen.py:416, in QWenAttention.forward(self, hidden_states, rotary_pos_emb_list, layer_past, attention_mask, head_mask, encoder_hidden_states, encoder_attention_mask, output_attentions, use_cache)
#     404 def forward(
#     405     self,
#     406     hidden_states: Optional[Tuple[torch.FloatTensor]],
#    (...)
#     414     use_cache: Optional[bool] = False,
#     415 ):
# --> 416     mixed_x_layer = self.c_attn(hidden_states)
#     418     query, key, value = mixed_x_layer.split(self.split_size, dim=2)
#     420     query = self._split_heads(query, self.num_heads, self.head_dim)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/anaconda3/lib/python3.11/site-packages/accelerate/hooks.py:164, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     163 def new_forward(module, *args, **kwargs):
# --> 164     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     165     if module._hf_hook.no_grad:
#     166         with torch.no_grad():
#
# File ~/anaconda3/lib/python3.11/site-packages/accelerate/hooks.py:335, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     328 for name, _ in named_module_tensors(
#     329     module,
#     330     include_buffers=self.offload_buffers,
#     331     recurse=self.place_submodules,
#     332     remove_non_persistent=True,
#     333 ):
#     334     fp16_statistics = None
# --> 335     value = self.weights_map[name]
#     336     if "weight" in name and name.replace("weight", "SCB") in self.weights_map.keys():
#     337         if value.dtype == torch.int8:
#
# File ~/anaconda3/lib/python3.11/site-packages/accelerate/utils/offload.py:118, in PrefixedDataset.__getitem__(self, key)
#     117 def __getitem__(self, key):
# --> 118     return self.dataset[f"{self.prefix}{key}"]
#
# File ~/anaconda3/lib/python3.11/site-packages/accelerate/utils/offload.py:170, in OffloadedWeightsLoader.__getitem__(self, key)
#     168 tensor = None
#     169 try:
# --> 170     with safe_open(weight_info["safetensors_file"], framework="pt", device=device) as f:
#     171         tensor = f.get_tensor(weight_info.get("weight_name", key))
#     172 except TypeError:
#     173     # if failed to get_tensor on the device, such as bf16 on mps, try to load it on CPU first
#
# File ~/anaconda3/lib/python3.11/site-packages/torch/storage.py:261, in _StorageBase.untyped(self)
#     258     else:
#     259         return cls._new_using_fd_cpu(size)
# --> 261 def untyped(self):
#     262     return self
#     264 def byteswap(self, dtype):
#
# KeyboardInterrupt:

# %%
history = None
while True:
    q = input('问题:')
    response, history = model.chat(tokenizer, q, history=history)
    print('history=>',history)
    print('ansowr=>',response)
    history = history[-5:]
# Out:
# 问题: 1+1=?
# history=> [('1+1=?', '1 + 1 = 2')]
# ansowr=> 1 + 1 = 2
# 问题: 1+2=?
# history=> [('1+1=?', '1 + 1 = 2'), ('1+2=?', '1 + 2 = 3')]
# ansowr=> 1 + 2 = 3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 3
#       1 history = None
#       2 while True:
# ----> 3     q = input('问题:')
#       4     response, history = model.chat(tokenizer, q, history=history)
#       5     print('history=>',history)
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
# 问题: KL
